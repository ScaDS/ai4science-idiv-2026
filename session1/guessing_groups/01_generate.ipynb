# %% [markdown]
# # Generating texts
# In this notebook we will generate texts and store them in a CSV file. More precisely, we generate random PhD topics which could potentially be worked on at the UFZ Leipzig structured as described in its [organigram](https://www.ufz.de/export/data/global/98993_organisation-chart_27-10-2025.jpg).

# %%
import bia_bob
import random

# %% [markdown]
# First, we test the connection to the LLM server.

# %%
def prompt_scadsai_llm(message:str, model="openai/gpt-oss-120b"):
    """A prompt helper function that sends a message to ScaDS.AI LLM server at 
    ZIH TU Dresden and returns only the text response.
    """
    import os
    import openai
    
    # convert message in the right format if necessary
    if isinstance(message, str):
        message = [{"role": "user", "content": message}]
    
    # setup connection to the LLM
    client = openai.OpenAI(base_url="https://llm.scads.ai/v1",
                           api_key=os.environ.get('SCADSAI_API_KEY')
    )
    response = client.chat.completions.create(
        model=model,
        messages=message
    )
    
    # extract answer
    return response.choices[0].message.content
     
prompt_scadsai_llm("hello world")
# Out:
# 'Hello! How can I help you today?'

# %% [markdown]
# Next, we define a couple of random first and lastnames. We also define a list of institutes.
# These will hint the LLM to generate PhD topics that are relevant to a given institute.

# %%
import pandas as pd
import numpy as np
import random

# Define separate lists for first names and last names
first_names = ["Alex", "Jordan", "Morgan", "Taylor", "Avery",
               "Sam", "Casey", "Riley", "Jamie", "Dakota",
               "Bailey", "Cameron", "Sydney", "Robin", "Charlie",
               "Dana", "Kris", "Skyler", "Devon", "Reese"]

last_names = ["Reed", "Smith", "Lee", "Garcia", "Patel",
              "Chen", "O'Hara", "Jain", "Kumar", "Singh",
              "Liu", "Davis", "Clark", "Thomas", "Brooks",
              "Flores", "Rivera", "Adams", "Gonzalez", "Campbell"]

faculties = """Biodiversity & People
Biodiversity Conservation
Biodiversity Economics
Biodiversity in the Anthropocene
Biodiversity Synthesis
Experimental Interaction Ecology
Physiological Diversity
Species Interaction Ecology
Theory in Biodiversity Science""".split("\n")
len(faculties), faculties[:10]
# Out:
# (9,
#  ['Biodiversity & People',
#   'Biodiversity Conservation',
#   'Biodiversity Economics',
#   'Biodiversity in the Anthropocene',
#   'Biodiversity Synthesis',
#   'Experimental Interaction Ecology',
#   'Physiological Diversity',
#   'Species Interaction Ecology',
#   'Theory in Biodiversity Science'])

# %% [markdown]
# In the following loop we select an institute name randomly and ask the LLM server to generate a PhD topic related to the chosen institute.

# %%
research_fields = faculties

# Set random seed for reproducibility
np.random.seed(42)
random.seed(42)

profiles = []

#for field in faculties:
while len(profiles) < 250:    
    # Random name generation from first and last name
    name = f"{random.choice(first_names)} {random.choice(last_names)}"
    field = random.choice(research_fields)

    topic = prompt_scadsai_llm(f"""Generate an English PhD thesis topic for someone working at a the Centre for Integrative Biodiversity Research in group '{field}'. Reply with only the title of the research project and nothing else.""")
    topic = topic.strip().replace("</s>", "").replace("\"", "")
    if ":" in topic and " " not in topic.split(":")[0]:
        topic = topic.split(":")[1]
    if "</thinking>" in topic:
        topic = topic.split("</thinking>")[1]

    print(len(topic), topic)
    
    profiles.append({
        "name": name,
        "research_field": field,
        "topic": topic
    })
# Out:
# 106 Integrative Modeling of Multi‑Taxon Functional Traits to Predict Ecosystem Resilience Under Climate Change
# 105 Quantifying the Economic Valuation of Pollinator-Driven Ecosystem Services under Climate Change Scenarios
# 112 Integrative Landscape Genomics for Enhancing Adaptive Capacity of Threatened Plant Species under Climate Change】
# 133 Integrating Traditional Ecological Knowledge and Genomic Data to Model Human-Driven Resilience in Agro‑Forest Biodiversity Landscapes
# 161 Integrating Genomic, Functional, and Landscape Approaches to Assess Resilience of Pollinator Communities Under Climate‑Driven Land‑Use Change in the Anthropocene
# 116 Assessing the Socio‑Ecological Impacts of Urban Green Infrastructure on Biodiversity Resilience and Human Well‑Being
# 92 Integrative Theoretical Models of Multiscale Species Coexistence in Heterogeneous Ecosystems
# 148 Network Dynamics of Mutualistic Interactions under Climate Change: Integrating Trait‑ and Phylogeny‑Based Approaches in Plant‑Pollinator Communities
# 168 Evaluating Community-Led Agroforestry as a Dual Strategy for Biodiversity Conservation and Socioeconomic Resilience: An Integrative Approach within Human–Nature Systems
# 135 Experimental Manipulation of Plant‑Pollinator Network Dynamics Under Climate Change: An Integrative Approach to Biodiversity Resilience
# 114 Functional Trait Dynamics of Urban Plant Communities: Implications for Biodiversity Resilience in the Anthropocene
# 116 Integrating Genomic, Landscape, and Socio‑Economic Data to Optimize Conservation Prioritization under Climate Change
# 133 Experimental Dissection of Multi‑Trophic Interaction Networks: Linking Functional Traits to Ecosystem Resilience under Climate Change
# 140 Integrative Modelling of Species Interaction Networks and Functional Trait Syndromes to Forecast Biodiversity Responses under Climate Change
# 154 Integrative Theoretical Models of Community Assembly: Linking Functional Trait Networks, Phylogenetic Structure, and Multidimensional Environmental Change
# 155 Integrating Genomics, Landscape Ecology, and Socioeconomic Indicators to Optimize Adaptive Conservation Strategies for Endemic Species under Climate Change
# 119 Experimental Manipulation of Multitrophic Interaction Networks to Elucidate Biodiversity Responses under Climate Change
# 133 Integrating Genomic, Landscape, and Socio‑Economic Data to Prioritize Climate‑Resilient Protected Areas for Biodiversity Conservation
# 118 Integrative Modeling of Functional Trait Evolution and Ecosystem Service Delivery Across Global Biodiversity Gradients
# 135 Integrating Genomic, Landscape, and Socioeconomic Data to Optimize Adaptive Management Strategies for Threatened Pollinator Communities
# 137 Integrating Network Theory and Functional Trait Diversity to Predict the Resilience of Plant–Pollinator Interactions under Climate Change
# 125 Manipulating Multi‑Trophic Interaction Networks: Experimental Approaches to Predict Ecosystem Resilience under Climate Change
# 117 Integrating Genomic, Trait, and Environmental Data to Model Global Functional Biodiversity Loss under Climate Change}
# 155 Integrating Market Mechanisms and Ecosystem Service Valuation: A Comparative Economic Framework for Biodiversity Conservation in Agro‑Ecological Landscapes
# 125 Valuing Ecosystem Services: An Integrated Economic Framework for Assessing Biodiversity Trade‑offs in Agricultural Landscapes
# 113 Integrative Modelling of Global Biodiversity Patterns Using Trait‑Based Synthesis and Machine‑Learning Approaches
# 135 Experimental Dissection of Multitrophic Interaction Networks under Climate Change: Linking Functional Traits to Biodiversity Resilience
# 134 Integrating Traditional Ecological Knowledge and Genomic Tools to Assess Adaptive Capacity of Pollinator Communities in Agroecosystems
# 122 Integrative Modelling of Species Interactions and Functional Traits to Predict Biodiversity Responses under Climate Change
# 124 Experimental Dissection of Multi‑Trophic Interaction Networks: Linking Plant–Herbivore–Microbe Dynamics under Climate Change
# 165 Integrative Assessment of Adaptive Physiological Diversity: Linking Thermal Tolerance Plasticity to Genomic and Ecosystem Resilience in Terrestrial Plant Communities
# 108 Integrative Modeling of Species Interaction Networks for Predicting Biodiversity Responses to Climate Change
# 113 Integrative Theoretical Framework for Predicting Species Coexistence under Multiscale Environmental Heterogeneity
# 117 Integrative Physiological Mechanisms Driving Plant Adaptation to Climate Extremes Across Global Biodiversity Hotspots
# 114 Experimental Manipulation of Multitrophic Interactions under Climate Change: Implications for Ecosystem Resilience
# 138 Integrative Modeling of Multi‑Scale Species Interactions: A Theoretical Framework for Predicting Biodiversity Dynamics under Global Change
# 127 Linking Urban Green Infrastructure to Biodiversity Conservation and Human Well‑Being: A Multi‑Scale Socio‑Ecological Assessment
# 144 Economic Valuation of Biodiversity: Developing Integrated Market and Non‑Market Instruments for Sustainable Conservation in Multi‑Use Landscapes
# 147 Integrative Modeling of Socio‑Ecological Resilience: Predicting Conservation Outcomes under Climate‑Driven Land‑Use Change in Biodiversity Hotspots
# 122 Integrating Network Theory and Functional Traits to Predict Climate‑Driven Shifts in Plant‑Pollinator Interaction Networks
# 97 Integrative Theoretical Framework for Predicting Community Assembly Dynamics under Climate Change
# 116 Integrative Theoretical Models of Community Assembly and Functional Diversity Dynamics under Global Change Scenarios
# 137 Integrating Genomic, Landscape, and Socioeconomic Data to Optimize Conservation Strategies for Endemic Plant Species under Climate Change
# 139 Economic Valuation of Functional Biodiversity: Integrating Ecosystem Service Markets with Indigenous Knowledge for Sustainable Conservation
# 126 Integrative Modeling of Phylogenetic, Functional Trait, and Genomic Data to Predict Biodiversity Responses under Global Change
# 102 Quantitative Frameworks for Predicting Community Assembly under Climate‑Driven Functional Trait Shifts
# 114 Integrating Functional Trait Networks and Spatial Dynamics to Predict Biodiversity Resilience under Climate Change
# 119 Economic Valuation of Functional Biodiversity: Integrating Ecosystem Services into Market-Based Conservation Strategies
# 126 Integrative Theoretical Models for Predicting Spatiotemporal Biodiversity Dynamics under Multi‑Stress Climate Change Scenarios
# 136 Experimental Manipulations of Multi‑Species Plant–Pollinator Networks to Uncover Mechanisms of Community Resilience under Climate Change
# 141 Integrating Genomic, Landscape, and Socioeconomic Approaches to Enhance Conservation Strategies for Keystone Species in Fragmented Ecosystems
# 116 Integrative Assessment of Anthropogenic Drivers Shaping Functional and Phylogenetic Biodiversity in Urban Ecosystems
# 119 Integrating Genomics and Landscape Ecology to Optimize Conservation Strategies for Endemic Species under Climate Change
# 153 Integrating Genomic, Landscape, and Socio‑economic Data to Prioritize Climate‑Resilient Conservation Corridors for Endemic Species in Fragmented Habitats
# 130 Economic Valuation of Biodiversity: Integrating Ecosystem Service Metrics and Market Mechanisms to Strengthen Conservation Policy
# 101 Integrative Modeling of Functional Trait Diversity Across Multiscale Ecosystems: A Synthesis Approach
# 123 Linking Intraspecific Physiological Trait Variation to Species Coexistence Across Elevational Gradients in Tropical Forests
# 142 Integrating Genomic and Remote Sensing Data to Quantify Functional Biodiversity Shifts under Anthropogenic Land‑Use Change in the Anthropocene
# 141 Experimental Dissection of Multi‑Species Interaction Networks under Climate Change: Linking Trait‑Mediated Effects to Biodiversity Resilience
# 129 Multiscale Network Modeling of Plant–Pollinator Interactions Under Climate Change: Integrating Functional Traits and Genomic Data
# 112 Integrative Genomic and Landscape Approaches to Predicting Species Resilience under Anthropogenic Climate Change
# 138 Integrating Traditional Ecological Knowledge and Genomic Data to Enhance Adaptive Management of Biodiversity in Human‑Dominated Landscapes
# 157 Integrative Modeling of Species Interactions and Functional Resilience in Anthropogenic Landscapes: A Multi-Scale Approach to Predicting Biodiversity Futures
# 155 Assessing the Socio‑Ecological Impacts of Urban Green Infrastructure on Biodiversity and Human Well‑Being: An Integrative Framework for Policy and Practice
# 131 Integrating Remote Sensing and Environmental DNA to Quantify Functional Biodiversity Shifts in Anthropogenically Altered Landscapes
# 142 Experimental Dissection of Multi‑Trophic Interaction Networks: Linking Functional Traits, Environmental Variability, and Biodiversity Outcomes
# 101 Adaptive Capacity of Tropical Plant Communities to Climate‑Driven Land‑Use Change in the Anthropocene
# 102 Integrative Genomic‑Eco‑Societal Modelling of Species Resilience to Climate Change in the Anthropocene
# 120 Network Dynamics of Multi‑Trophic Mutualisms: Integrating Temporal and Spatial Scales to Predict Biodiversity Resilience
# 139 Integrative Omics of Thermal Tolerance: Linking Metabolic Plasticity, Gene Regulation, and Species Distribution in Alpine Plant Communities
# 144 Integrative Landscape Genomics and Socio‑Ecological Modeling for Enhancing Adaptive Conservation Strategies in Fragmented Biodiversity Hotspots.
# 90 Integrative Physiology of Climate‑Driven Phenotypic Plasticity in Alpine Plant Communities
# 131 Socio‑Ecological Dynamics of Urban Green Spaces: Integrating Biodiversity Conservation and Human Well‑Being in Community Landscapes
# 126 Integrative Trait-Physiology of Alpine Plant Species under Climate Change: Linking Genomic Variation to Functional Adaptations
# 167 Integrating Genomics, Functional Traits, and Landscape Dynamics to Assess Invertebrate Biodiversity Resilience under Climate‑Driven Land‑Use Change in the Anthropocene
# 103 Integrative Theoretical Modelling of Biodiversity Dynamics under Multi‑Stressor Global Change Scenarios
# 158 Linking Functional Trait Plasticity to Climate Resilience: A Multi‑Species Comparative Study of Plant Water‑Use Physiology Across Alpine Biodiversity Hotspots
# 118 Predicting Cascading Effects of Climate-Driven Phenological Shifts on Multitrophic Plant–Pollinator–Herbivore Networks
# 163 Integrative Modeling of Multi‑Trophic Network Dynamics to Predict Climate‑Driven Shifts in Plant–Pollinator and Herbivore Interactions Across Fragmented Landscapes
# 140 Integrating Traditional Ecological Knowledge and Socio‑Ecological Modelling to Enhance Biodiversity Resilience in Human‑Dominated Landscapes
# 142 Integrative Genomic and Landscape Modeling of Climate‑Resilient Corridors for Endemic Species Conservation in Fragmented Biodiversity Hotspots
# 118 Physiological Trait Plasticity and Ecosystem Resilience: An Integrative Multi‑Scale Analysis Across Climatic Gradients
# 129 Functional Trait Resilience of Urban Pollinator Communities under Climate Change and Land‑Use Intensification in the Anthropocene
# 145 Economic Valuation of Pollinator Services in Agricultural Landscapes: Integrating Biodiversity Metrics with Market‑Based Conservation Instruments
# 107 Thermal Tolerance Plasticity and Evolutionary Trajectories of Alpine Plant Communities under Climate Change
# 123 Integrative Synthesis of Functional and Phylogenetic Diversity Metrics to Predict Ecosystem Resilience under Climate Change
# 150 Integrative Network Modeling of Multi-Trophic Species Interactions under Climate Change: Bridging Functional Traits, Phylogeny, and Landscape Dynamics
# 133 Integrating Multi‑Omics, Trait Databases, and Remote Sensing to Model Global Biodiversity Patterns and Predict Climate‑Driven Shifts.
# 170 Integrative Spatiotemporal Modeling of Biodiversity Patterns: A Unified Theoretical Framework Linking Species Interactions, Evolutionary History, and Environmental Change
# 116 Assessing the Socio‑Ecological Impacts of Urban Green Infrastructure on Biodiversity Resilience and Human Well‑Being
# 149 Integrative Network Models of Evolutionary Dynamics: Linking Species Interactions, Landscape Heterogeneity, and Climate Change in Biodiversity Theory
# 145 Ecosystem Services and Cultural Resilience: Assessing the Role of Traditional Knowledge in Biodiversity Conservation Across Rural‑Urban Gradients
# 132 Valuing Ecosystem Services: An Integrated Economic Framework for Biodiversity Conservation in Climate‑Resilient Agroforestry Systems
# 119 Thermal Plasticity and Metabolic Scaling Across Alpine Plant Species: An Integrative Physiological and Genomic Approach
# 121 Assessing Functional Trait Shifts and Ecosystem Resilience of Temperate Forests under Multi‑Stressors in the Anthropocene
# 156 Cultural Ecosystem Services and Adaptive Management: Integrating Indigenous Knowledge to Enhance Biodiversity Resilience in Urban–Rural Interface Landscapes
# 101 Trait-Based Modeling of Thermal Tolerance Plasticity Across Alpine Plant Species Under Climate Change
# 126 Integrative Theoretical Framework for Predicting Multi‑Scale Biodiversity Responses to Climate‑Driven Multi‑Stressor Scenarios
# 125 Integrative Genomic and Functional Trait Approaches to Predicting Species Resilience under Rapid Anthropogenic Climate Change
# 101 Integrative Modeling of Functional Trait Networks to Predict Ecosystem Resilience under Global Change
# 118 Integrative Modeling of Functional Trait Networks to Predict Community Resilience under Multi‑Stress Climate Scenarios
# 156 Integrating Genomics, Landscape Ecology, and Socio‑Economic Drivers to Prioritize Conservation Actions for Threatened Endemic Species in Fragmented Habitats
# 123 Integrating Genomic and Landscape Approaches to Prioritize Conservation Actions for Threatened Species under Climate Change
# 98 Functional Resilience of Pollinator Networks under Climate and Land‑Use Change in the Anthropocene
# 141 Economic Valuation of Species Diversity: Integrating Market Mechanisms and Conservation Outcomes in Multiscale Biodiversity Policy Frameworks
# 107 Functional Resilience of Urban Pollinator Networks under Climate‑Driven Land‑Use Change in the Anthropocene
# 151 Valuing Ecosystem Services: Integrating Market Mechanisms and Indigenous Knowledge for Sustainable Biodiversity Conservation in Agroforestry Landscapes
# 111 Integrative Modelling of Multi‑Scale Species Interactions to Predict Biodiversity Responses under Global Change
# 101 Narratives of Coexistence: Community Storytelling as a Tool for Integrative Biodiversity Conservation
# 151 Integrating Landscape Genomics and Socio‑Ecological Modeling to Optimize Conservation Strategies for Threatened Keystone Species in Fragmented Habitats
# 123 Integrative Genomic and Landscape Modelling of Keystone Species for Adaptive Biodiversity Conservation under Climate Change
# 118 Integrating Economic Valuation and Genetic Diversity: A Framework for Optimizing Biodiversity Conservation Investments
# 151 Integrative Multi-omics and Remote Sensing Approaches to Quantify Functional Biodiversity Shifts in Urban Ecosystems under Anthropogenic Climate Change
# 116 Integrative Trait–Phylogeny Synthesis for Predictive Modeling of Global Biodiversity Patterns Across Temporal Scales
# 119 Integrative Modeling of Species Interactions and Functional Traits to Predict Community Resilience under Climate Change
# 127 Linking Plant Hydraulic Traits to Climate Resilience: An Integrative Physiological Approach across Global Biodiversity Hotspots
# 137 Integrating Traditional Ecological Knowledge and Genomic Data to Co‑Design Community‑Based Conservation Strategies for Threatened Species
# 111 Valuing Ecosystem Services: An Integrated Economic Framework for Biodiversity Conservation under Climate Change
# 122 Integrative Metabolomic and Transcriptomic Analyses of Climate‑Driven Physiological Plasticity in Alpine Plant Communities
# 116 Integrative Genomics and Landscape Ecology for Adaptive Conservation Strategies of Threatened Pollinator Communities
# 110 A Unified Theoretical Framework for Predicting Multiscale Biodiversity Responses to Anthropogenic Disturbances
# 120 Integrative Theoretical Framework for Predicting Community Assembly under Climate Change: A Multi‑Scale Network Approach
# 120 Valuing Ecosystem Services: An Integrated Economic Framework for Assessing Biodiversity Loss in Agro‑Forestry Landscapes
# 147 Functional Trait-Mediated Plant‑Pollinator Interaction Networks under Climate Change: Experimental Approaches to Predicting Biodiversity Resilience
# 130 Assessing Functional Resilience of Urban Pollinator Networks under Climate Change and Land-Use Intensification in the Anthropocene
# 104 Experimental Dissection of Multi‑Trophic Interaction Networks under Climate‑Driven Habitat Fragmentation
# 136 Valuing Ecosystem Services: Integrating Market and Non‑Market Mechanisms to Finance Biodiversity Conservation in Agricultural Landscapes
# 145 Integrating Economic Valuation of Ecosystem Services with Genetic Diversity Metrics: A Multi‑Scale Framework for Biodiversity Conservation Policy
# 135 Valuing Ecosystem Services: Integrating Economic Valuation Methods with Biodiversity Conservation Strategies in Agricultural Landscapes
# 111 Integrative Genomic and Landscape Approaches to Assessing Species Resilience under Anthropogenic Climate Change
# 156 Integrating Landscape Genomics and Socio‑Ecological Modeling to Predict Climate‑Resilient Strategies for Endemic Species Conservation in Fragmented Habitats
# 91 Network Dynamics of Plant–Pollinator Interactions under Climate‑Induced Phenological Shifts
# 128 Network Dynamics of Multi‑Trophic Species Interactions under Climate Change: An Integrative Empirical and Computational Approach
# 127 Integrative Assessment of Functional Biodiversity Resilience to Climate‑Driven Land‑Use Change in Urban Anthropocene Landscapes
# 127 Multi‑Scale Assessment of Functional Resilience in Pollinator Networks under Climate‑Driven Land‑Use Change in the Anthropocene
# 100 Integrative Modelling of Functional Biodiversity and Ecosystem Resilience under Rapid Climate Change
# 116 Disentangling Multispecies Interaction Networks: Experimental Approaches to Context‑Dependent Biodiversity Functions
# 132 A Unifying Theoretical Framework for Multi‑Scale Biodiversity Patterns: Integrating Functional, Phylogenetic, and Spatial Dimensions
# 115 Integrative Meta-Analyses of Functional Trait Diversity and Ecosystem Resilience Across Global Biogeographic Realms
# 104 Integrative Modelling of Species Interaction Networks to Predict Biodiversity Responses to Global Change
# 117 Thermal Tolerance Plasticity and Its Role in Predicting Alpine Plant Species Distribution Shifts Under Climate Change
# 94 Integrative Multi‑Omics Dissection of Thermal Tolerance Mechanisms Across Alpine Plant Species
# 128 Integrative Genomic and Socio‑Ecological Strategies for Enhancing Landscape‑Scale Biodiversity Conservation under Climate Change
# 130 Evaluating the Adaptive Capacity of Tropical Plant-Pollinator Networks to Climate and Land-Use Transformations in the Anthropocene
# 112 Integrative Physiological Mechanisms Driving Drought Resilience in Alpine Plant Communities under Climate Change
# 115 Integrating Network Theory and Multi‑Scale Spatial Dynamics to Predict Biodiversity Resilience under Climate Change
# 139 Linking Thermal Stress Physiology to Community Assembly: A Multi‑Species, Multi‑Scale Analysis of Climate Resilience in Alpine Biodiversity
# 129 Experimental Dissection of Mutualistic Networks: Linking Trait-Mediated Interactions to Community Resilience under Climate Change
# 108 Integrative Theoretical Frameworks for Predicting Biodiversity Responses to Multi‑Scale Environmental Change
# 108 Experimental Manipulation of Multi‑Trophic Interactions to Predict Community Resilience under Climate Change
# 143 Towards a Unified Theoretical Framework for Multiscale Biodiversity Dynamics: Integrating Evolutionary, Ecological, and Functional Perspectives
# 144 Integrative Metabolomics and Functional Trait Plasticity: Unraveling Plant Physiological Diversity across Climate Gradients in Alpine Ecosystems
# 124 Integrative Modelling of Species Interactions: A Synthesis Framework for Predicting Biodiversity Responses to Climate Change
# 127 Integrating Traditional Ecological Knowledge and Genomic Data to Model Human Impacts on Landscape-Scale Biodiversity Resilience
# 148 Assessing Adaptive Capacity of Fragmented Ecosystems: Integrative Genomic and Functional Approaches to Biodiversity Conservation in the Anthropocene
# 130 Experimental Dissection of Multi‑Trophic Interaction Networks Under Climate Change: An Integrative Approach in Interaction Ecology
# 119 Network Dynamics of Multitrophic Interactions under Climate Change: Integrating Trait‑Based and Phylogenetic Approaches
# 91 Multiscale Network Modeling of Plant–Pollinator Interaction Resilience under Climate Change
# 111 Integrative Modeling of Global Species Interaction Networks to Predict Biodiversity Responses to Climate Change
# 118 Experimental Manipulation of Multi‑Species Interaction Networks to Predict Biodiversity Responses under Climate Change
# 115 Integrative Modelling of Functional and Phylogenetic Diversity to Predict Ecosystem Resilience under Climate Change
# 149 Integrating Economic Valuation of Ecosystem Services with Biodiversity Conservation Priorities: A Multi‑Scale Framework for Sustainable Policy Design
# 129 Integrative Genomic and Landscape Modeling of Species Resilience to Climate‐Driven Anthropogenic Disturbances in the Anthropocene
# 170 Integrating Genomic, Landscape, and Socioeconomic Data to Optimize Adaptive Management Strategies for Climate-Resilient Biodiversity Conservation in Fragmented Ecosystems
# 132 Integrative Genomic and Landscape Analyses of Adaptive Resilience in Fragmented Temperate Forests under Anthropogenic Climate Change
# 145 Physiological Trait Plasticity and Adaptive Strategies of Alpine Plant Species Across Elevational Gradients: An Integrative Biodiversity Approach
# 117 Assessing the Socio‑Ecological Impacts of Urban Green Infrastructure on Pollinator Diversity and Community Well‑Being
# 148 Integrative Modelling of Multi‑Trophic Resilience: Predicting Biodiversity Trajectories under Climate Change and Human Pressures in the Anthropocene
# 85 Network Dynamics of Multi‑Trophic Mutualisms under Climate‑Driven Phenological Shifts
# 159 Integrating Genomic Resilience and Landscape Connectivity: Predicting Species Adaptation to Climate and Land‑Use Change in the Anthropocene Biodiversity Crisis
# 124 Integrating Economic Valuation and Genetic Diversity Metrics: A Comprehensive Framework for Biodiversity Conservation Policy
# 137 Integrative Theoretical Frameworks for Predicting Community Assembly under Climate Change: Bridging Trait‑Based Models and Network Theory
# 116 Integrating Multi‑modal Network Approaches to Predict Climate‑Driven Shifts in Plant–Pollinator Interaction Networks
# 112 Integrative Physiology of Trait Plasticity: Assessing Climate Resilience Across Alpine and Lowland Plant Species
# 124 Integrating Economic Valuation of Ecosystem Services with Dynamic Biodiversity Models to Inform Sustainable Policy Decisions
# 101 Integrating Multi‑Omics and Trait‑Based Modeling to Predict Community Resilience under Climate Change
# 120 Integrative Theoretical Modelling of Multi‑Scale Species Interactions and Community Assembly in Heterogeneous Landscapes
# 122 Integrative Modeling of Global Functional and Phylogenetic Biodiversity Patterns Using Multi‑Omics and Remote Sensing Data
# 113 Integrative Modeling of Functional and Phylogenetic Diversity to Predict Ecosystem Resilience under Global Change
# 118 Experimental Manipulation of Multi‑Trophic Interaction Networks to Unravel Biodiversity Responses Under Climate Change
# 135 Integrating Genomic and Socio‑Ecological Data to Optimize Landscape‑Scale Conservation Strategies for Threatened Pollinator Communities
# 161 Functional Trait Shifts in Urban-Adapted Pollinator Communities under Climate Change: An Integrative Assessment for Biodiversity Conservation in the Anthropocene
# 132 Integrative Genomic and Landscape Analyses of Resilience Mechanisms in Keystone Species under Anthropogenic Climate Change Pressures
# 110 Integrating Trait-Based and Network Theory to Model Biodiversity Resilience Under Multifactorial Global Change
# 151 Cultural Ecosystem Services and Genetic Diversity: Assessing Community‑Driven Conservation Strategies in Agro‑Forest Landscapes across the Global South
# 150 Adaptive Metabolic Strategies and Thermal Tolerance in Tropical Plant Communities: Integrating Physiological Diversity with Climate Change Projections
# 147 Integrative Mechanisms of Phenotypic Plasticity: Linking Genomic Diversity to Physiological Resilience of Alpine Plant Species under Climate Change
# 164 Experimental Dissection of Multi‑Species Interaction Networks: Linking Functional Traits, Environmental Stressors, and Community Resilience in Biodiverse Ecosystems
# 126 Linking Functional Trait Variation to Climate Resilience: A Comparative Physiological Analysis Across Alpine Plant Communities
# 104 Functional Trait Turnover and Ecosystem Resilience under Accelerated Land‑Use Change in the Anthropocene
# 110 Integrating Genomic, Trait, and Environmental Data to Model Global Plant Community Responses to Climate Change
# 140 Cultural Keystone Species: Integrating Indigenous Knowledge and Genomic Data to Assess Their Role in Landscape‑Level Biodiversity Resilience
# 121 Integrative Multi‑Scale Analysis of Plant Physiological Traits Driving Climate Adaptation in Global Biodiversity Hotspots
# 116 Valuing Ecosystem Services: Integrating Economic Incentives and Biodiversity Conservation in Agricultural Landscapes
# 123 Assessing the Socio‑Ecological Impacts of Urban Green Infrastructure on Native Pollinator Networks and Community Well‑Being
# 131 Integrating Traditional Ecological Knowledge and Genomic Data to Assess the Resilience of Agroforestry Systems under Climate Change
# 115 Economic Valuation of Genetic Diversity: Integrating Biodiversity Metrics into Market-Based Conservation Strategies
# 138 Integrating Traditional Ecological Knowledge and Genomic Data to Model Human Impacts on Pollinator Biodiversity in Agricultural Landscapes
# 140 Experimental Dissection of Multi‑Trophic Interaction Networks Under Climate Change: Linking Functional Biodiversity and Ecosystem Resilience
# 107 Experimental Investigation of Multi‑Trophic Interaction Networks under Climate‑Driven Habitat Fragmentation
# 132 Integrative Modeling of Global Biodiversity Patterns: Synthesizing Phylogenetic, Functional, and Environmental Drivers Across Scales
# 102 Integrating Socio‑Ecological Indicators for Adaptive Management of Mediterranean Biodiversity Hotspots
# 144 A Unified Theoretical Framework for Multi‑Scale Biodiversity Patterns: Integrating Trait Evolution, Species Interactions, and Ecosystem Function
# 153 Integrative Modelling of Species Interaction Networks under Climate Change and Urbanization: Implications for Biodiversity Resilience in the Anthropocene
# 137 Cultural Ecosystem Services and Adaptive Governance: Integrating Traditional Knowledge with Biodiversity Conservation in Rural Landscapes
# 147 Cultural Ecosystem Services and Climate Resilience: Integrating Traditional Knowledge into Biodiversity Conservation Strategies in Rural Landscapes
# 131 Ecocritical Narratives of the Anthropocene: Literary Depictions of Biodiversity Loss and Resilience in Contemporary English Fiction
# 120 Integrating Landscape Genomics and Socio‑Ecological Modeling for Adaptive Conservation of Fragmented Forest Biodiversity
# 151 Integrating Functional Traits, Phylogenetics, and Climate‑Driven Network Dynamics to Predict Resilience in Multitrophic Species Interaction Communities
# 152 Economic Valuation of Pollinator-Dependent Agriculture under Climate Change: Integrating Biodiversity Metrics with Market-Based Conservation Instruments
# 122 Integrating Genomic and Landscape Approaches to Prioritize Conservation Corridors for Endemic Species under Climate Change
# 132 Integrating Genomic, Landscape, and Socio‑Economic Data to Optimize Conservation Strategies for Endemic Species under Climate Change
# 133 Integrative Meta-Analyses of Global Pollinator Declines: Synthesizing Trait-Based Drivers and Ecosystem Service Impacts Across Biomes
# 115 Integrative Multi‑Omics Dissection of Thermal Tolerance Mechanisms Across Alpine Plant Species Under Climate Change
# 149 Integrative Assessment of Taxonomic, Functional, and Phylogenetic Diversity Loss in Terrestrial Ecosystems under Accelerating Anthropogenic Pressures
# 155 Integrating Genomic, Landscape, and Socio‑Economic Data to Optimize Adaptive Conservation Strategies for Threatened Keystone Species in Fragmented Habitats
# 138 Experimental Manipulation of Multi‑Trophic Interaction Networks under Climate Change: Implications for Biodiversity and Ecosystem Function
# 100 Experimental Dissection of Plant‑Pollinator Network Resilience to Climate‑Driven Phenological Shifts
# 151 Integrative Physiology of Plant Metabolic Plasticity: Linking Intraspecific Trait Variation to Climate Resilience Across Alpine and Tropical Ecosystems
# 120 Integrative Genomics and Phenotypic Plasticity of Thermal Tolerance across Alpine Plant Communities under Climate Change
# 150 Economic Valuation of Biodiversity-Driven Ecosystem Services: Integrating Multi-Scale Market and Non‑Market Mechanisms for Sustainable Land‑Use Policy
# 117 Integrating Functional Trait Networks and Phylogenetic Diversity to Predict Ecosystem Resilience under Climate Change
# 165 Integrative Theoretical Framework for Predicting Species Coexistence under Global Change: Linking Functional Trait Networks with Spatiotemporal Biodiversity Dynamics
# 155 Integrative Analysis of Functional Trait Plasticity and Climate Resilience in Alpine Plant Species: Linking Physiological Diversity to Ecosystem Adaptation
# 133 Experimental Dissection of Multi‑Trophic Interaction Networks under Climate Change: Linking Functional Traits to Community Resilience
# 111 Integrative Meta-Analytic Framework for Predicting Ecosystem Functionality Across Global Biodiversity Gradients
# 140 Network Dynamics of Multi‑Trophic Mutualisms: Integrating Trait‑Based Modelling and Empirical Data to Predict Resilience under Global Change
# 129 Integrative Functional Genomics of Thermal Tolerance: Linking Physiological Diversity to Climate Resilience Across Plant Lineages
# 131 Integrative Network Analysis of Plant–Pollinator Interaction Dynamics under Climate Change Using Functional Traits and Genomic Data
# 113 Integrating Network Theory and Genomic Tools to Elucidate Multi‑Trophic Interaction Dynamics under Climate Change
# 111 Integrating Remote Sensing and eDNA Data to Model Temporal Dynamics of Global Biodiversity Under Climate Change
# 110 Integrative Multi‑Omics Modeling of Global Biodiversity Patterns and Ecosystem Resilience under Climate Change
# 148 Multiscale Theoretical Frameworks for Predicting Biodiversity Response to Global Change: Integrating Trait-Based, Phylogenetic, and Spatial Dynamics
# 144 Integrative Genomic and Remote‑Sensing Approaches to Quantify Species Redistribution and Functional Resilience of Ecosystems in the Anthropocene
# 112 A Unified Theoretical Framework for Predicting Biodiversity Responses to Multi-Stressor Climate Change Scenarios
# 131 Trait-Mediated Indirect Effects and Climate-Driven Rewiring of Plant–Pollinator Interaction Networks Across Environmental Gradients
# 119 Integrating Remote Sensing and Community-Based Monitoring to Evaluate Protected Area Effectiveness Under Climate Change
# 150 Integrative Physiology of Plant Trait Plasticity: Linking Genomic, Metabolic, and Ecosystem Responses to Climate Variability Across Biodiverse Regions
# 102 Experimental Dissection of Multi‑Trophic Interaction Networks under Climate‑Driven Phenological Shifts
# 94 Integrative Theoretical Models of Multi‑Scale Biodiversity Dynamics under Rapid Climate Change
# 119 Towards a Unified Theoretical Framework for Predicting Multiscale Biodiversity Patterns from Trait‑Interaction Networks
# 110 Integrative Genomic and Network Approaches to Decipher Multi‑Trophic Interaction Dynamics under Climate Change
# 138 Integrating Multi‑Scale Genomic, Trait, and Environmental Data to Model Global Biodiversity Patterns and Forecast Climate‑Change Responses
# 101 Functional Resilience of Pollinator Communities to Climate-Driven Land‑Use Change in the Anthropocene
# 87 Mathematical Frameworks for Predicting Community Assembly Dynamics under Climate Change
# 104 Integrative Genomic‑Ecological Modeling of Species Resilience under Accelerating Anthropogenic Pressures
# 103 Scaling Laws and Emergent Dynamics of Multi‑Trophic Biodiversity Networks under Global Change Pressures
# 128 Integrating Genomic, Landscape, and Socio‑economic Data to Predict and Mitigate Biodiversity Loss in Fragmented Tropical Forests
# 132 Integrating Genomic, Functional Trait, and Landscape Modelling to Predict Biodiversity Resilience under Anthropogenic Climate Change
# 123 Integrative Modeling of Functional Trait Evolution and Community Assembly in Global Plant Biodiversity under Climate Change

# %% [markdown]
# Finally, we store the names, institutes and PhD topics to a csv file.

# %%
# Create DataFrame and save CSV
df = pd.DataFrame(profiles)
df.to_csv("phd_topics.csv", index=False)

df.head()
# Out:
#            name                    research_field  \
# 0   Taylor Reed            Biodiversity Synthesis
# 1    Riley Jain            Biodiversity Economics
# 2  Taylor Adams         Biodiversity Conservation
# 3  Devon Thomas             Biodiversity & People
# 4      Alex Lee  Biodiversity in the Anthropocene
#
#                                                topic
# 0  Integrative Modeling of Multi‑Taxon Functional...
# 1  Quantifying the Economic Valuation of Pollinat...
# 2  Integrative Landscape Genomics for Enhancing A...
# 3  Integrating Traditional Ecological Knowledge a...
# 4  Integrating Genomic, Functional, and Landscape...
